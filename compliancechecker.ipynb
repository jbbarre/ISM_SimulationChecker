# %%
import os
import xarray as xr
import pandas as pd
import datetime
import numpy as np

# %% [markdown]
# ## Load ISMIP Variables

# %%
ismip  = pd.read_csv('/mnt/d/1_protect/0_sanity_check/ismip_variable.csv',delimiter=';')
ismip.head()
# Out:
#     variable variable_alias    dim type                  name  \
# 0      lithk            NaN  x,y,t   ST         Ice thickness
# 1       orog            NaN  x,y,t   ST     Surface elevation
# 2       base            NaN  x,y,t   ST        Base elevation
# 3       topg            NaN  x,y,t   ST     Bedrock elevation
# 4  hfgeoubed            NaN  x,y,t   FL  Geothermal heat flux
#
#                              standard_name  \
# 0                       land_ice_thickness
# 1                         surface_altitude
# 2                            base_altitude
# 3                         bedrock_altitude
# 4  upward_geothermal_heat_flux_in_land_ice
#
#                                     alias_name  units  min_value  max_value
# 0                                          NaN      m          0       1000
# 1                                          NaN      m          0       1000
# 2                                          NaN      m          0       1000
# 3                                          NaN      m          0       1000
# 4  upward_geothermal_heat_flux_at_ground_level  W m-2          0       1000

# %%
ismip_meta = ismip.to_dict('records')
ismip_meta
# Out:
# [{'variable': 'lithk',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Ice thickness',
#   'standard_name': 'land_ice_thickness',
#   'alias_name': nan,
#   'units': 'm',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'orog',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Surface elevation',
#   'standard_name': 'surface_altitude',
#   'alias_name': nan,
#   'units': 'm',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'base',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Base elevation',
#   'standard_name': 'base_altitude',
#   'alias_name': nan,
#   'units': 'm',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'topg',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Bedrock elevation',
#   'standard_name': 'bedrock_altitude',
#   'alias_name': nan,
#   'units': 'm',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'hfgeoubed',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Geothermal heat flux',
#   'standard_name': 'upward_geothermal_heat_flux_in_land_ice',
#   'alias_name': 'upward_geothermal_heat_flux_at_ground_level',
#   'units': 'W m-2',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'acabf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Surface mass balance flux',
#   'standard_name': 'land_ice_surface_specific_mass_balance_flux',
#   'alias_name': nan,
#   'units': 'kg m-2 s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'libmassbfgr',
#   'variable_alias': '\xa0libmassbf',
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Basal mass balance flux beneath grounded ice',
#   'standard_name': 'land_ice_basal_specific_mass_balance_flux',
#   'alias_name': nan,
#   'units': 'kg m-2 s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'libmassbffl',
#   'variable_alias': '\xa0libmassbf',
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Basal mass balance flux beneath floating ice',
#   'standard_name': 'land_ice_basal_specific_mass_balance_flux',
#   'alias_name': nan,
#   'units': 'kg m-2 s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'dlithkdt',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Ice thickness imbalance',
#   'standard_name': 'tendency_of_land_ice_thickness',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'xvelsurf',
#   'variable_alias': '\xa0uvelsurf',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Surface velocity in x',
#   'standard_name': 'land_ice_surface_x_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'yvelsurf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Surface velocity in y',
#   'standard_name': 'land_ice_surface_y_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'zvelsurf',
#   'variable_alias': '\xa0wvelsurf',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Surface velocity in z',
#   'standard_name': 'land_ice_surface_upward_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'xvelbase',
#   'variable_alias': '\xa0uvelbase',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Basal velocity in x',
#   'standard_name': 'land_ice_basal_x_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'yvelbase',
#   'variable_alias': '\xa0vvelbase',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Basal velocity in y',
#   'standard_name': 'land_ice_basal_y_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'zvelbase',
#   'variable_alias': '\xa0wvelbase',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Basal velocity in z',
#   'standard_name': 'land_ice_basal_upward_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'xvelmean',
#   'variable_alias': '\xa0uvelmean',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Mean velocity in x',
#   'standard_name': 'land_ice_vertical_mean_x_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'yvelmean',
#   'variable_alias': '\xa0vvelmean',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Mean velocity in y',
#   'standard_name': 'land_ice_vertical_mean_y_velocity',
#   'alias_name': nan,
#   'units': 'm s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'litemptop',
#   'variable_alias': '\xa0litempsnic',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Surface temperature',
#   'standard_name': 'temperature_at_top_of_ice_sheet_model',
#   'alias_name': 'temperature_at_ground_level_in_snow_or_firn',
#   'units': 'K',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'litempbotgr',
#   'variable_alias': '\xa0litempbot',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Basal temperature beneath grounded ice sheet',
#   'standard_name': 'temperature_at_base_of_ice_sheet_model\xa0',
#   'alias_name': 'land_ice_basal_temperature',
#   'units': 'K',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'litempbotfl',
#   'variable_alias': '\xa0litempbot',
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Basal temperature beneath floating ice shelf',
#   'standard_name': 'temperature_at_base_of_ice_sheet_model',
#   'alias_name': 'land_ice_basal_temperature',
#   'units': 'K',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'strbasemag',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Basal drag',
#   'standard_name': 'land_ice_basal_drag',
#   'alias_name': 'magnitude_of_land_ice_basal_drag',
#   'units': 'Pa',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'licalvf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Calving flux',
#   'standard_name': 'land_ice_specific_mass_flux_due_to_calving',
#   'alias_name': nan,
#   'units': 'kg m-2 s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'lifmassbf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Ice front melt and calving flux',
#   'standard_name': 'land_ice_specific_mass_flux_due_to_calving_and_ice_front_melting',
#   'alias_name': nan,
#   'units': 'kg m-2 s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'ligroundf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'FL',
#   'name': 'Grounding line flux',
#   'standard_name': 'land_ice_specific_mass_flux_at_grounding_line',
#   'alias_name': nan,
#   'units': 'kg m-2 s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'sftgif',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Land ice area fraction',
#   'standard_name': 'land_ice_area_fraction',
#   'alias_name': nan,
#   'units': '1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'sftgrf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Grounded ice sheet area fraction',
#   'standard_name': 'grounded_ice_sheet_area_fraction',
#   'alias_name': nan,
#   'units': '1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'sftflf',
#   'variable_alias': nan,
#   'dim': 'x,y,t',
#   'type': 'ST',
#   'name': 'Floating ice sheet area fraction',
#   'standard_name': 'floating_ice_shelf_area_fraction',
#   'alias_name': 'floating_ice_sheet_area_fraction',
#   'units': '1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'lim',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'ST',
#   'name': 'Total ice mass',
#   'standard_name': 'land_ice_mass',
#   'alias_name': nan,
#   'units': 'kg',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'limnsw',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'ST',
#   'name': 'Mass above floatation',
#   'standard_name': 'land_ice_mass_not_displacing_sea_water',
#   'alias_name': nan,
#   'units': 'kg',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'iareagr',
#   'variable_alias': '\xa0iareag',
#   'dim': 't',
#   'type': 'ST',
#   'name': 'Grounded ice area',
#   'standard_name': 'grounded_ice_sheet_area',
#   'alias_name': 'grounded_land_ice_area',
#   'units': 'm^2',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'iareafl',
#   'variable_alias': '\xa0iareaf',
#   'dim': 't',
#   'type': 'ST',
#   'name': 'Floating ice area',
#   'standard_name': 'floating_ice_shelf_area',
#   'alias_name': nan,
#   'units': 'm^2',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'tendacabf',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'FL',
#   'name': 'Total SMB flux',
#   'standard_name': 'tendency_of_land_ice_mass_due_to_surface_mass_balance',
#   'alias_name': nan,
#   'units': 'kg s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'tendlibmassbf',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'FL',
#   'name': 'Total BMB flux',
#   'standard_name': 'tendency_of_land_ice_mass_due_to_basal_mass_balance',
#   'alias_name': nan,
#   'units': 'kg s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'tendlibmassbffl',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'FL',
#   'name': 'Total BMB flux beneath floating ice',
#   'standard_name': 'tendency_of_land_ice_mass_due_to_basal_mass_balance',
#   'alias_name': nan,
#   'units': 'kg s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'tendlicalvf',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'FL',
#   'name': 'Total calving flux',
#   'standard_name': 'tendency_of_land_ice_mass_due_to_calving',
#   'alias_name': nan,
#   'units': 'kg s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'tendlifmassbf',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'FL',
#   'name': 'Total calving and ice front melting flux',
#   'standard_name': 'tendency_of_land_ice_mass_due_to_calving_and_ice_front_melting',
#   'alias_name': nan,
#   'units': 'kg s-1',
#   'min_value': 0,
#   'max_value': 1000},
#  {'variable': 'tendligroundf',
#   'variable_alias': nan,
#   'dim': 't',
#   'type': 'FL',
#   'name': 'Total grounding line flux',
#   'standard_name': 'tendency_of_grounded_ice_mass',
#   'alias_name': nan,
#   'units': 'kg s-1',
#   'min_value': 0,
#   'max_value': 1000}]

# %%
# get the list of variables
ismip_var = [dic['variable'] for dic in ismip_meta]

# %% [markdown]
# ## Explore directory

# %%
source_path = '/mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1'

# %%
def list_files(path):
    for root,dirs,files in os.walk(path):
        level = root.replace(path,'').count(os.sep)
        indent = ' ' * 4 *(level)
        print(f'{indent}{os.path.basename(root)}/')
        subindent = '  '*4*(level+1)
        for f in files:
            print(f'{subindent}{f}')

#list_files(source_path)

# %%
def files_and_subdirectories(root_path):
    files = []
    directories = []
    for f in os.listdir(root_path):
        if os.path.isfile(f):
            files.append(f)
        elif os.path.isdir(f):
            directories.append(f)
    return directories, files

directories,files = files_and_subdirectories(source_path)

print(directories)
# Out:
# []

# %% [markdown]
# ## Check a single file

# %%
#file = '/mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1/exp05_32/acabf_AIS_IMAU_IMAUICE1_exp05.nc'
#!scalar! file = '/mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1/abmb_32/iareafl_AIS_IMAU_IMAUICE1_abmb.nc'
file = '/mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1/exp05_32/libmassbffl_AIS_IMAU_IMAUICE1_exp05.nc'
#file = '/mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1/exp05_32/orog_AIS_IMAU_IMAUICE1_exp05.nc'
ds = xr.open_dataset(file)
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 86, y: 191, x: 191, nv: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 2015-07-01 2016-07-01 ... 2100-07-01
#   * x            (x) float32 -3.04e+06 -3.008e+06 ... 3.008e+06 3.04e+06
#   * y            (y) float32 -3.04e+06 -3.008e+06 ... 3.008e+06 3.04e+06
# Dimensions without coordinates: nv
# Data variables:
#     libmassbffl  (time, y, x) float32 ...
#     mapping      |S1 ...
#     time_bounds  (time, nv) datetime64[ns] ...
# Attributes:
#     NCO:                        netCDF Operators version 4.7.7 (Homepage = ht...
#     Conventions:                CF-1.7
#     info:                       Model IMAUICE1, Institute for Marine and Atmo...
#     contact:                    Heiko Goelzer, h.goelzer@uu.nl
#     history:                    Thu Oct 17 20:34:52 2019: ncks -A -v time,tim...
#     history_of_appended_files:  Thu Oct 17 20:34:52 2019: Appended file ../Da...

# %%
file_var = list(ds.data_vars)
errors = 0
warnings = 0

for ivar in file_var:
    if ivar in ismip_var:
        print('* ',ivar, 'is a valid name.')
        # get index in the ismip_var list
        var_index = [k for k in range(len(ismip_var)) if ismip_var[k]==ivar]
        # check the unit
        if ds[ivar].attrs['units'] == ismip_meta[var_index[0]]['units']:
            print('the unit is correct:',ds[ivar].attrs['units'])

        else:
            print('the current variable\'s unit is',ds[ivar].attrs['units'],'and should be',ismip_meta[var_index[0]]['units'],'Please check.')
            warnings = warnings + 1 
        # check the min,max,mean values
        if ds[ivar].min()>ismip_meta[var_index[0]]['min_value']:
            print('The minimum value successfully verified.')
        else:
            print('The minimum value(', round(ds[ivar].min().values.item(0),5),') is out of range. Please check it!')
            errors = errors + 1 
        if ds[ivar].max()>ismip_meta[var_index[0]]['max_value']:
                print('The maximum value successfully verified.')
        else:
            print('The maximum value(', round(ds[ivar].max().values.item(0),5),') is out of range. Please check it!')
            errors = errors + 1

        #SPATIAL: Check spatial extent of the grid
        coords = ds.coords.to_dataset()
        Xbottomleft=int(min(coords['x']).values.item())
        Ybottomleft=int(min(coords['y']).values.item())
        Xtopright=int(max(coords['x']).values.item())
        Ytopright=int(max(coords['y']).values.item())

        if Xbottomleft == -3040000 & Ybottomleft == -3040000:
            print( 'Lowest left corner of the grid is well defined.')
        else:    
            print('Lowest left corner of the grid is not well defined. [-3040000,-3040000] Expected')
            errors = errors + 1
        if Xtopright ==3040000 & Ytopright ==3040000:
            print('Upper right corner is well defined.')
        else:    
            print('Upper rigth corner of the grid is not well defined. [3040000,3040000] Expected')
            errors = errors + 1

        #SPATIAL:check the spatial resolution
        spatial_resolution = 32
        Xresolution = (coords['x'][1].values-coords['x'][0].values)/1000
        Yresolution = (coords['y'][1].values-coords['y'][0].values)/1000
        if Xresolution == spatial_resolution and Yresolution == spatial_resolution:
            print('The spatial resolution (grid size) was successfully verified.')
        else:
            print('The spatial resolution ( ', Xresolution,'or',Yresolution,') is different of ',spatial_resolution,' km. Please check it!','\n')
            error = error + 1

        # Time: experiment duration
        start_exp = min(ds['time']).values.astype('datetime64[D]')
        end_exp  = max(ds['time']).values.astype('datetime64[D]')
        print("Start of the experiment:", start_exp.astype('datetime64[D]'))
        print("End of the experiment:", end_exp.astype('datetime64[D]'))

        # Time: time resolution
        time_step = ds['time'].values[11]-ds['time'].values[10]
        print('Time step:',time_step.astype('timedelta64[D]').item().days,'days','\n')

    else:
        print(ivar,'isn\'t a known variable name. Its verification has been ignored.','\n')

print(errors,' critical errors identified in',file,'. It can\'t be shared as it is.')
print(errors,' warnings identified in',file,'. Please, check before sharing.')
# Out:
# *  libmassbffl is a valid name.
# the unit is correct: kg m-2 s-1
# The minimum value( -0.00037 ) is out of range. Please check it!
# The maximum value( 0.00011 ) is out of range. Please check it!
# Lowest left corner of the grid is well defined.
# Upper right corner is well defined.
# The spatial resolution (grid size) was successfully verified.
# Start of the experiment: 2015-07-01
# End of the experiment: 2100-07-01
# Time step: 365 days
#
# mapping isn't a known variable name. Its verification has been ignored.
#
# time_bounds isn't a known variable name. Its verification has been ignored.
#
# 2  critical errors identified in /mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1/exp05_32/libmassbffl_AIS_IMAU_IMAUICE1_exp05.nc . It can't be shared as it is.
# 2  warnings identified in /mnt/d/1_protect/0_sanity_check/IMAU/IMAUICE1/exp05_32/libmassbffl_AIS_IMAU_IMAUICE1_exp05.nc . Please, check before sharing.

# %%
# Out:
# -3040000.0
# 3040000.0
# -3040000.0
# 3040000.0

# %%
ds.coords['y'].shape
# Out:
# (191,)

# %%
ds['libmassbffl']
# Out:
# <xarray.DataArray 'libmassbffl' (time: 86, y: 191, x: 191)>
# array([[[nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan],
#         ...,
#         [nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan]],
#
#        [[nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan],
#         ...,
#         [nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan]],
#
#        ...,
#
#        [[nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan],
#         ...,
#         [nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan]],
#
#        [[nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan],
#         ...,
#         [nan, nan, ..., nan, nan],
#         [nan, nan, ..., nan, nan]]], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-07-01 2016-07-01 ... 2100-07-01
#   * x        (x) float32 -3.04e+06 -3.008e+06 -2.976e+06 ... 3.008e+06 3.04e+06
#   * y        (y) float32 -3.04e+06 -3.008e+06 -2.976e+06 ... 3.008e+06 3.04e+06
# Attributes:
#     units:          kg m-2 s-1
#     standard_name:  land_ice_basal_specific_mass_balance_flux
